# %% [markdown]
# ##### The Following is derived from a case study I completed on recommendations. For privacy and confidentiality, I've altered all of the IDS, locations, and job types in the dataset.

# %% [markdown]
# # K-Nearest Neighbors Weighting

# %% [markdown]
# ### In February 2021, I completed a case with a large corporation whose business model relies on recommendation algorithms. The case asked for predictions based on the data offered. Here, I improve upon that case by experimenting with weighting variables in a KNN algorithm in order to give more importance to certain factors.

# %% [markdown]
# ### Background: The dataset includes nearly 4000 users who have applied to a job. We have information on the user's career level, their location, their education, and we have information on the job they applied to: its location, education, and type.

# %% [markdown]
# ### Our task is to predict for each user what three jobs they are likely to apply to next. Let's start.

# %%
#imports
import pandas as pd
import numpy as np
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt

# %%
#Let's look at the data

df = pd.read_csv('case_data.csv')
df.head()
# Out:
#                                  USERID                                 JOBID  \
# 0  003650a8-ae65-4d0d-9211-f9b7ae2ba87f  1c91a60f-8c98-4f4e-a8d2-b2b907ffa959
# 1  be6510b5-6a32-4123-bcb0-1691423ab4d3  1c91a60f-8c98-4f4e-a8d2-b2b907ffa959
# 2  1cce0c54-be4c-471f-aa2a-468e55ca5924  1c91a60f-8c98-4f4e-a8d2-b2b907ffa959
# 3  73bcb589-68c0-47f0-bf7b-c8ac5ef7353a  c82d255a-eae5-46e7-b727-7ba59737f184
# 4  79e36f7f-d84a-4876-8f30-e97576c9b5bf  9eb0aaf0-8bc3-4e11-80df-53d78020c439
#
#   UserState                            CAREERLEVEL  \
# 0  Illinois  Manager (Manager/Supervisor of Staff)
# 1  Illinois                  Student (High School)
# 2  Illinois  Manager (Manager/Supervisor of Staff)
# 3   Montana              Experienced (Non-Manager)
# 4  Illinois              Experienced (Non-Manager)
#
#                               UserEd       JobState  \
# 0  Some College Coursework Completed       Illinois
# 1                        Unspecified       Illinois
# 2  Some College Coursework Completed       Illinois
# 3                   Bachelors Degree        Montana
# 4                   Bachelors Degree  Massachusetts
#
#                        JobEd       JobType
# 0  High School or equivalent  CONSTRUCTION
# 1  High School or equivalent  CONSTRUCTION
# 2  High School or equivalent  CONSTRUCTION
# 3           Bachelors Degree       MEDICAL
# 4           Bachelors Degree       FINANCE

# %% [markdown]
# #### Remove any whitespace from columns

# %%
df_obj = df.select_dtypes(['object'])
df[df_obj.columns] = df_obj.apply(lambda x: x.str.strip())

# %% [markdown]
# ## EDA

# %% [markdown]
# #### Let's look at some of the locations

# %%
df.UserState.sample(20)
# Out:
# 2138          Bristol
# 1264          Alabama
# 795        California
# 2676             Ohio
# 1600         New York
# 3585          Arizona
# 3057         Colorado
# 1224            Texas
# 3243    Massachusetts
# 1456         New York
# 2577         Virginia
# 3062    Massachusetts
# 1109            Texas
# 1691         Colorado
# 3486          Florida
# 2325          Florida
# 2558         New York
# 703             Texas
# 3520          Florida
# 1083            Texas
# Name: UserState, dtype: object

# %% [markdown]
# #### Notice Bristol--It looks like there are foreign locations, so let's find out which ones

# %%
state_names = ["Alaska", "Alabama", "Arkansas", "American Samoa", "Arizona", "California", "Colorado", "Connecticut", "District ", "of Columbia", "Delaware","District of Columbia", "Florida", "Georgia", "Guam", "Hawaii", "Iowa", "Idaho", "Illinois", "Indiana", "Kansas", "Kentucky", "Louisiana", "Massachusetts", "Maryland", "Maine", "Michigan", "Minnesota", "Missouri", "Mississippi", "Montana", "North Carolina", "North Dakota", "Nebraska", "New Hampshire", "New Jersey", "New Mexico", "Nevada", "New York", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Puerto Rico", "Rhode Island", "South Carolina", "South Dakota", "Tennessee", "Texas", "Utah", "Virginia", "Virgin Islands", "Vermont", "Washington", "Wisconsin", "West Virginia", "Wyoming"]
#Create df of foreign locations
foreign = df[df.UserState.apply(lambda x: False if x in state_names else True)]
print(foreign.UserState.value_counts())
# Out:
# Madrid        48
# London        39
# Manchester    37
# Bristol       21
# Birmingham    20
# Paris         17
# Prague        10
# Wales          6
# Ontario        6
# Dublin         5
# Alberta        3
# Berlin         2
# Rome           2
# Sao Paulo      2
# Tokyo          2
# Scotland       1
# Z�rich         1
# Quebec         1
# Brussels       1
# Kyoto          1
# Frankfurt      1
# Name: UserState, dtype: int64

# %% [markdown]
# #### Where are those in foreign countries applying?

# %%
#lets look at the locations of the jobs of users applying in Madrid
print(foreign[foreign.UserState=='Madrid']['JobState'].value_counts())
# Out:
# Madrid     45
# Bristol     3
# Name: JobState, dtype: int64

# %%
print(foreign[foreign.UserState=='London']['JobState'].value_counts())
# Out:
# London        31
# Prague         2
# Bristol        2
# Scotland       2
# Birmingham     1
# Name: JobState, dtype: int64

# %% [markdown]
# #### Looks like most users in other countries are applying to jobs in their city and country, but there are exceptions

# %%
print('UNIQUE STATES: ',sorted(list(df.UserState.unique()), key=str.lower))
# Out:
# UNIQUE STATES:  ['Alabama', 'Alberta', 'Arizona', 'Arkansas', 'Berlin', 'Birmingham', 'Bristol', 'Brussels', 'California', 'Colorado', 'Connecticut', 'Delaware', 'District of Columbia', 'Dublin', 'Florida', 'Frankfurt', 'Georgia', 'Guam', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Kyoto', 'London', 'Louisiana', 'Madrid', 'Maine', 'Manchester', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Ontario', 'Oregon', 'Paris', 'Pennsylvania', 'Prague', 'Puerto Rico', 'Quebec', 'Rhode Island', 'Rome', 'Sao Paulo', 'Scotland', 'South Carolina', 'Tennessee', 'Texas', 'Tokyo', 'Utah', 'Vermont', 'Virgin Islands', 'Virginia', 'Wales', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming', 'Z�rich']

# %% [markdown]
# #### Let's replace that value in Zurich (It's been imported as ''Z�rich")

# %%
df['UserState'] = df['UserState'].replace('Z�rich','Zurich')
print(sorted(list(df.UserState.unique()), key=str.lower, reverse=True)[0])
# Out:
# Zurich

# %% [markdown]
# ## Regions

# %% [markdown]
# ### Let's generalize all locations and create regions so that if there aren't matching jobs in a state, we can look at nearby places

# %% [markdown]
# ### If I'm applying to a Job in Boston, I'm more likely to be interested in jobs in New York City than in Los Angeles

# %%
us_state_abbrev = {'Alabama': 'AL','Alaska': 'AK','American Samoa': 'AS','Arizona': 'AZ','Arkansas': 'AR','California': 'CA',
    'Colorado': 'CO','Connecticut': 'CT','Delaware': 'DE','District of Columbia': 'DC','Florida': 'FL','Georgia': 'GA',
    'Guam': 'GU','Hawaii': 'HI','Idaho': 'ID','Illinois': 'IL','Indiana': 'IN','Iowa': 'IA','Kansas': 'KS','Kentucky': 'KY',
    'Louisiana': 'LA','Maine': 'ME','Maryland': 'MD','Massachusetts': 'MA','Michigan': 'MI','Minnesota': 'MN',
    'Mississippi': 'MS','Missouri': 'MO','Montana': 'MT','Nebraska': 'NE','Nevada': 'NV','New Hampshire': 'NH',
    'New Jersey': 'NJ','New Mexico': 'NM','New York': 'NY','North Carolina': 'NC','North Dakota': 'ND','Northern Mariana Islands':'MP',
    'Ohio': 'OH','Oklahoma': 'OK','Oregon': 'OR','Pennsylvania': 'PA','Puerto Rico': 'PR','Rhode Island': 'RI',
    'South Carolina': 'SC','South Dakota': 'SD','Tennessee': 'TN','Texas': 'TX','Utah': 'UT','Vermont': 'VT',
    'Virgin Islands': 'VI','Virginia': 'VA','Washington': 'WA','West Virginia': 'WV','Wisconsin': 'WI','Wyoming': 'WY'}

state_regions = {'AK': 'O','AL': 'S','AR': 'S','AS': 'O','AZ': 'W','CA': 'W','CO': 'W','CT': 'N','DC': 'N','DE': 'N',
        'FL': 'S','GA': 'S','GU': 'O','HI': 'O','IA': 'M','ID': 'W','IL': 'M','IN': 'M','KS': 'M','KY': 'S','LA': 'S',
        'MA': 'N','MD': 'N','ME': 'N','MI': 'W','MN': 'M','MO': 'M','MP': 'O','MS': 'S','MT': 'W','NA': 'O','NC': 'S',
        'ND': 'M','NE': 'W','NH': 'N','NJ': 'N','NM': 'W','NV': 'W','NY': 'N','OH': 'M','OK': 'S','OR': 'W','PA': 'N',
        'PR': 'O','RI': 'N','SC': 'S','SD': 'M','TN': 'S','TX': 'S','UT': 'W','VA': 'S','VI': 'O','VT': 'N','WA': 'W',
        'WI': 'M','WV': 'S','WY': 'W'}

foreign = {'Madrid':'SP','London':'UK','Manchester':'UK','Bristol':'UK','Birmingham':'UK','Paris':'FR',
           'Prague':'CR','Ontario':'CAN', 'Wales':'UK','Dublin':'IR','Alberta':'CAN','Rome':'IT',
           'Tokyo':'JP','Berlin':'GER','Sao Paulo':'BRA','Zurich':'SW','Brussels':'BEL','Quebec':'CAN',         
           'Scotland':'UK','Kyoto':'JP','Frankfurt':'GER','Normandy':'FR','Galway':'IR','Vienna':'AUS','Amsterdam':'NETH',
          'Toronto':'CAN','Dresden':'GER'}

# %% [markdown]
# #### Let's create a variable for country

# %%
df['job_country'] = df.JobState.apply(lambda x: 'USA' if x in list(us_state_abbrev.keys()) else (foreign.get(x,np.NaN)))
df['user_country'] = df.UserState.apply(lambda x: 'USA' if x in list(us_state_abbrev.keys()) else (foreign.get(x,np.NaN)))

# %% [markdown]
# #### And one for region

# %%
def get_region(row, column):
        if row[column] in list(us_state_abbrev.keys()):
            return state_regions[us_state_abbrev[row[column]]]
        elif row[column] in list(foreign.keys()):
            return foreign[row[column]]
        else:
            return np.NaN

df['job_region'] = df.apply(lambda x: get_region(x, 'JobState'), axis=1)
df['user_region'] = df.apply(lambda x: get_region(x, 'UserState'), axis=1)

# %% [markdown]
# #### Note: The region variable won't add much value to positions outside of the U.S. for multiple reasons: for one, there aren't enough observations for region to pull in similar jobs within a region. Second, my knowledge of European regional geography leaves much to be desired, so with my limited time, researching all of the localities and dividing the nations seemed like an inefficient use of my time.

# %% [markdown]
# #### As a substitute, I added the country variable: rather than recommending a position in Italy to a user who applied to a position in the U.K., this variable led the algorithm to recommend other positions in the U.K. In addition, within the U.S., this variable added weight to positions within the country even if they weren’t in the same region.

# %%
print('Number of entries without a region: ', len(df[df.job_region.isnull()]))
# Out:
# Number of entries without a region:  5

# %%
df[df.job_region.isnull()]
# Out:
#                                     USERID  \
# 38    e89cd6fa-ee9e-4473-b7d9-065fd1e09ae9
# 1736  2981a7c0-a9cf-46f6-a609-ffac2207244b
# 1940  1afd76ab-942e-4388-9dcb-32b5bb31c09d
# 2817  7cf17b97-2d96-4f1d-b8a9-261980f72d6f
# 3162  39c6e386-f43f-45b6-9298-6650ea182bba
#
#                                      JOBID      UserState  \
# 38    0efcbc05-a30e-4575-8c7d-972a8c0d1776   Pennsylvania
# 1736  4208d49a-7b5a-4713-894d-8ad23f83428a  West Virginia
# 1940  af6c4a58-f5cc-4fa0-b743-8d7cbf62cf30         Dublin
# 2817  fcf7cc45-d398-4f3b-88ba-dc51ad8cdb13         London
# 3162  df7d2e52-0326-462e-92f2-1e14bfcfc5f1     California
#
#                                 CAREERLEVEL                    UserEd  \
# 38                Experienced (Non-Manager)  Vocational - High School
# 1736              Experienced (Non-Manager)               Unspecified
# 1940                            Entry Level                Vocational
# 2817              Experienced (Non-Manager)          Bachelors Degree
# 3162  Manager (Manager/Supervisor of Staff)          Bachelors Degree
#
#      JobState                      JobEd       JobType job_country  \
# 38        NaN  High School or equivalent  CONSTRUCTION         NaN
# 1736      NaN  High School or equivalent  CONSTRUCTION         NaN
# 1940      NaN           Bachelors Degree       FINANCE         NaN
# 2817      NaN           Bachelors Degree       FINANCE         NaN
# 3162      NaN           Bachelors Degree       FINANCE         NaN
#
#      user_country job_region user_region
# 38            USA        NaN           N
# 1736          USA        NaN           S
# 1940           IR        NaN          IR
# 2817           UK        NaN          UK
# 3162          USA        NaN           W

# %%
df.sample(10)
# Out:
#                                     USERID  \
# 1700  750f75d8-593d-437d-99ca-06bf257ef4d3
# 1981  6e74179d-48e7-4f10-8a6e-c132555069f5
# 2031  5fd89aca-d67f-4c26-8cdd-2ef994e6e518
# 3486  ff2fbb96-4e60-4490-ab98-7a960714c0fe
# 1863  1d337763-9ec7-46a8-8fbd-115075b597c5
# 1642  76e6a621-2a64-4462-9d16-3d7a87f91273
# 1289  0fbbfb25-57ef-440f-848b-4401d68310bb
# 3484  74f6fe3a-951d-4e81-847f-c78b910b90d7
# 1393  49da6afb-a252-4ec1-b41e-67bc897309e4
# 2765  4949f335-b861-4205-bd62-7f70c238b86f
#
#                                      JOBID      UserState  \
# 1700  d5280b53-2a33-482a-b097-c4e3f4c09f30          Texas
# 1981  615dcf4b-e3ad-4641-a20a-f1c265fe8291        Indiana
# 2031  332e5aed-fc6f-422a-bf1a-515657e5c777       New York
# 3486  8c66ef11-4947-4c00-8b0a-b5d7a7dc65ee        Florida
# 1863  4cf6e5c4-129f-4056-88f7-cf2d6042bd96     Washington
# 1642  f5fe742e-8bc9-4b93-8f3a-d624934e2855       Kentucky
# 1289  b93b1658-b73d-4f85-ab9e-ecb74f2b4c04     New Jersey
# 3484  74b8f864-5953-4499-b7ca-92019250f100      Tennessee
# 1393  a886101e-2c1b-44ba-9679-4c752896d369  West Virginia
# 2765  1b96bcae-671e-4355-963d-e9affc36de26          Texas
#
#                                 CAREERLEVEL  \
# 1700  Manager (Manager/Supervisor of Staff)
# 1981              Experienced (Non-Manager)
# 2031  Manager (Manager/Supervisor of Staff)
# 3486       Student (undergraduate/graduate)
# 1863       Student (undergraduate/graduate)
# 1642              Experienced (Non-Manager)
# 1289       Student (undergraduate/graduate)
# 3484              Experienced (Non-Manager)
# 1393              Experienced (Non-Manager)
# 2765  Manager (Manager/Supervisor of Staff)
#
#                                  UserEd   JobState                      JobEd  \
# 1700                        Unspecified      Texas  High School or equivalent
# 1981                        Unspecified    Indiana  High School or equivalent
# 2031                   Bachelors Degree   New York  High School or equivalent
# 3486                        Unspecified    Florida  High School or equivalent
# 1863                   Bachelors Degree   New York           Bachelors Degree
# 1642                        Unspecified      Texas           Bachelors Degree
# 1289          High School or equivalent   New York  High School or equivalent
# 3484                        Unspecified  Tennessee  High School or equivalent
# 1393  Some College Coursework Completed       Ohio               Professional
# 2765                        Unspecified      Texas           Bachelors Degree
#
#            JobType job_country user_country job_region user_region
# 1700  CONSTRUCTION         USA          USA          S           S
# 1981  CONSTRUCTION         USA          USA          M           M
# 2031  CONSTRUCTION         USA          USA          N           N
# 3486  CONSTRUCTION         USA          USA          S           S
# 1863       FINANCE         USA          USA          N           W
# 1642       FINANCE         USA          USA          S           S
# 1289       FINANCE         USA          USA          N           N
# 3484       MEDICAL         USA          USA          S           S
# 1393  CONSTRUCTION         USA          USA          M           S
# 2765       FINANCE         USA          USA          S           S

# %% [markdown]
# ### Location exploration

# %% [markdown]
# #### Are applicants applying to jobs in different countries?

# %%
print('Count of users applying outside their country: ', len(df[df.apply(lambda x: True if x['job_country'] != x['user_country'] else False, axis=1)]))
# Out:
# Count of users applying outside their country:  41

# %% [markdown]
# #### Looks like only a few, but lets see if there any patterns among them

# %%
df[df.apply(lambda x: True if x['job_country'] != x['user_country'] else False, axis=1)]
# Out:
#                                     USERID  \
# 38    e89cd6fa-ee9e-4473-b7d9-065fd1e09ae9
# 200   2581517a-d08a-4da0-8942-aeb495179a94
# 268   5d85427e-1512-4727-8147-ff4ffbc8ec17
# 645   5d85427e-1512-4727-8147-ff4ffbc8ec17
# 894   60978e79-4d23-40f0-bd0c-6a7b420adb60
# 1167  b57068ab-99b2-4b19-8244-f7af03c69430
# 1595  c6fc0b81-83e0-4e84-97a1-e454490bcfa2
# 1649  59465faf-2c21-4dc8-9457-65349ee33fc9
# 1731  df943a4d-1d8c-4f8e-ac8e-c46b86499d60
# 1736  2981a7c0-a9cf-46f6-a609-ffac2207244b
# 1802  349cff3e-4a7e-4c8a-9662-11aa8fb1c254
# 1940  1afd76ab-942e-4388-9dcb-32b5bb31c09d
# 2021  13ddf3cb-24ca-44e3-a38b-4699f6d093ef
# 2054  5f5681c1-1d6e-410c-85c3-9bba40a38cca
# 2094  54489003-ca60-4a03-9451-b61726ca9415
# 2208  c19a5f21-228b-4dac-a499-c065ed0b2b94
# 2209  b31741d6-5fa8-4490-ae73-be5c78f458b7
# 2210  63491453-8840-490f-aa69-7dcd4d2112c5
# 2211  120696fc-e65c-47f3-a1ed-6da193cab02a
# 2212  9e77566c-33d6-4a5a-bc30-33b51c9edd14
# 2489  86a1202f-99fa-40de-b13f-bc4ae3cf7ac4
# 2524  d5ca7994-c5c1-49ba-8553-d796a5c62cdf
# 2624  ac9a80d3-59e5-4539-97de-e1e622fd922f
# 2625  ac9a80d3-59e5-4539-97de-e1e622fd922f
# 2779  547f9f55-1d38-426b-ac0c-d089af68f1f1
# 2817  7cf17b97-2d96-4f1d-b8a9-261980f72d6f
# 2844  4b232d54-0cad-4d32-9d97-bd0a6f0e38e5
# 2869  b2f9b3a4-5b90-4ac4-ba12-7caca47450b6
# 3051  0d03d717-ea37-4d5f-8f52-9c57708a744c
# 3064  63edaf92-fb8d-4e99-b0d2-0cc66dc6509a
# 3101  92075b21-de18-45ff-8293-43127606baff
# 3153  2723ecaa-423b-4a41-ab9b-4de4693491b4
# 3154  2723ecaa-423b-4a41-ab9b-4de4693491b4
# 3162  39c6e386-f43f-45b6-9298-6650ea182bba
# 3257  7be96f9b-0d64-4c67-a670-00b8f80f59b4
# 3260  70944f40-4aae-4b35-afe8-d678572ee3c2
# 3265  f1c6f346-201b-4233-8cbd-eeb56d9792d6
# 3293  e227c4fa-c9af-4ced-94fc-45c1744455a8
# 3308  d2949669-6ece-421f-9edd-357163345be5
# 3361  242c1602-0737-479e-bb39-43468ad026a5
# 3466  7e7269a9-700f-4424-95d2-565ea4f05276
#
#                                      JOBID      UserState  \
# 38    0efcbc05-a30e-4575-8c7d-972a8c0d1776   Pennsylvania
# 200   8db5cf9f-c6e7-45f4-930c-c8578774f6bb         Prague
# 268   8c786fdb-8ed5-4c7d-bfd3-549bc1627f96         Dublin
# 645   9f94bdb1-13c4-4c2e-bef6-a4c36b626cf3         Dublin
# 894   88adc908-af65-470e-b375-b66b059b5e1a         Prague
# 1167  af7422e3-9ec7-4f14-813f-05f803872d49          Tokyo
# 1595  c10a827c-e48d-4ff1-ad17-f704073f1cc1         London
# 1649  0db15dbd-0f88-4a0a-a74e-2081a7b00157      Sao Paulo
# 1731  d18466d1-9877-4269-a781-b875a61410e2        Bristol
# 1736  4208d49a-7b5a-4713-894d-8ad23f83428a  West Virginia
# 1802  22dad9e7-61ec-4413-b64d-08c17b475d18          Tokyo
# 1940  af6c4a58-f5cc-4fa0-b743-8d7cbf62cf30         Dublin
# 2021  84051891-45e0-4b13-a502-7c0679d9f37e      Minnesota
# 2054  5d1113d4-383c-4488-b524-e05a0bb315ae          Kyoto
# 2094  698f81a4-6fa7-4b86-aa3e-48320c584220           Rome
# 2208  4b7142af-eb6b-4de6-aed9-4b916f216dc5     California
# 2209  4b7142af-eb6b-4de6-aed9-4b916f216dc5     California
# 2210  4b7142af-eb6b-4de6-aed9-4b916f216dc5          Texas
# 2211  4b7142af-eb6b-4de6-aed9-4b916f216dc5     California
# 2212  4b7142af-eb6b-4de6-aed9-4b916f216dc5     California
# 2489  cd2e69e6-bc60-454d-be20-b3126561e6f9         Prague
# 2524  11db0465-f454-4648-b21d-19cd52cdb3b9         Prague
# 2624  7f455145-006a-4a9b-ad3f-dc964a623fd1     California
# 2625  32b3472a-1570-4c1a-9dac-137991a0e043     California
# 2779  ca3ee092-5af2-4f27-b52d-49fded4f01de         Prague
# 2817  fcf7cc45-d398-4f3b-88ba-dc51ad8cdb13         London
# 2844  6413d5e0-9c62-4215-83f5-e83d39449dd9         Madrid
# 2869  fb74a50c-9dcd-476c-b414-93ff498b5043       Maryland
# 3051  b78bf9ff-ea50-4ad0-94a8-f7b6cc97a581       New York
# 3064  3007c4e2-f39c-4ab2-8f7b-e4967b3aa2da      Sao Paulo
# 3101  ff8f65c1-26ee-461e-b2c1-76e75f9e2292       Brussels
# 3153  6139fd91-9ace-46d8-bdff-6454ada1ce20        Bristol
# 3154  96672839-73d5-418a-b4d2-48ec6378f699        Bristol
# 3162  df7d2e52-0326-462e-92f2-1e14bfcfc5f1     California
# 3257  8215369a-a173-42ab-8f4c-c73731b96c53         Prague
# 3260  8a4e33ac-36ba-4064-a146-2e9276ec8465         Madrid
# 3265  126aa81b-a1f5-459d-814d-ff2a3cb42f15         Madrid
# 3293  426eb7e6-af42-4932-8248-c8ee6e354318         London
# 3308  2e930bb3-eaf2-412d-8e09-54e03cbb9b35     Birmingham
# 3361  ac2e2775-e80c-4cc3-961e-41e8202afe8e     Birmingham
# 3466  c2b6b56e-3104-41d1-916a-c883b54b859d       New York
#
#                                 CAREERLEVEL  \
# 38                Experienced (Non-Manager)
# 200        Student (undergraduate/graduate)
# 268               Experienced (Non-Manager)
# 645               Experienced (Non-Manager)
# 894        Student (undergraduate/graduate)
# 1167              Experienced (Non-Manager)
# 1595              Experienced (Non-Manager)
# 1649              Experienced (Non-Manager)
# 1731                            Entry Level
# 1736              Experienced (Non-Manager)
# 1802              Experienced (Non-Manager)
# 1940                            Entry Level
# 2021                            Entry Level
# 2054              Experienced (Non-Manager)
# 2094                  Student (High School)
# 2208              Experienced (Non-Manager)
# 2209              Experienced (Non-Manager)
# 2210                            Entry Level
# 2211                            Entry Level
# 2212  Manager (Manager/Supervisor of Staff)
# 2489                  Student (High School)
# 2524              Experienced (Non-Manager)
# 2624              Experienced (Non-Manager)
# 2625              Experienced (Non-Manager)
# 2779  Manager (Manager/Supervisor of Staff)
# 2817              Experienced (Non-Manager)
# 2844                  Student (High School)
# 2869  Manager (Manager/Supervisor of Staff)
# 3051              Experienced (Non-Manager)
# 3064  Manager (Manager/Supervisor of Staff)
# 3101              Experienced (Non-Manager)
# 3153  Manager (Manager/Supervisor of Staff)
# 3154  Manager (Manager/Supervisor of Staff)
# 3162  Manager (Manager/Supervisor of Staff)
# 3257                            Entry Level
# 3260                            Entry Level
# 3265                  Student (High School)
# 3293              Experienced (Non-Manager)
# 3308  Manager (Manager/Supervisor of Staff)
# 3361              Experienced (Non-Manager)
# 3466       Student (undergraduate/graduate)
#
#                                  UserEd       JobState  \
# 38             Vocational - High School            NaN
# 200                         Unspecified         London
# 268                         Unspecified       New York
# 645                         Unspecified       New York
# 894                         Unspecified         London
# 1167                     Masters Degree       New York
# 1595                        Unspecified         Prague
# 1649                   Bachelors Degree  Massachusetts
# 1731                        Unspecified         Madrid
# 1736                        Unspecified            NaN
# 1802                   Bachelors Degree     California
# 1940                         Vocational            NaN
# 2021                        Unspecified         London
# 2054                   Bachelors Degree     California
# 2094                        Unspecified     California
# 2208                     Masters Degree         Vienna
# 2209                        Unspecified         Vienna
# 2210                     Masters Degree         Vienna
# 2211  Some College Coursework Completed         Vienna
# 2212                        Unspecified         Vienna
# 2489                        Unspecified         London
# 2524                        Unspecified         London
# 2624                        Unspecified      Amsterdam
# 2625                        Unspecified         Zurich
# 2779                        Unspecified         London
# 2817                   Bachelors Degree            NaN
# 2844                        Unspecified        Bristol
# 2869                        Unspecified        Dresden
# 3051                        Unspecified         Berlin
# 3064                        Unspecified         London
# 3101                        Unspecified         Berlin
# 3153                        Unspecified         Madrid
# 3154                        Unspecified         Madrid
# 3162                   Bachelors Degree            NaN
# 3257                        Unspecified         London
# 3260                        Unspecified        Bristol
# 3265                        Unspecified        Bristol
# 3293                        Unspecified         Prague
# 3308                        Unspecified     California
# 3361                        Unspecified         Madrid
# 3466           Vocational - High School         Zurich
#
#                                   JobEd       JobType job_country  \
# 38            High School or equivalent  CONSTRUCTION         NaN
# 200                       Certification  CONSTRUCTION          UK
# 268                    Bachelors Degree       FINANCE         USA
# 645                    Bachelors Degree       FINANCE         USA
# 894           High School or equivalent  CONSTRUCTION          UK
# 1167  Some College Coursework Completed       FINANCE         USA
# 1595        Some High School Coursework  CONSTRUCTION          CR
# 1649                   Bachelors Degree       FINANCE         USA
# 1731        Some High School Coursework  CONSTRUCTION          SP
# 1736          High School or equivalent  CONSTRUCTION         NaN
# 1802                   Bachelors Degree  CONSTRUCTION         USA
# 1940                   Bachelors Degree       FINANCE         NaN
# 2021                   Bachelors Degree       FINANCE          UK
# 2054                   Bachelors Degree  CONSTRUCTION         USA
# 2094                   Bachelors Degree       FINANCE         USA
# 2208                   Bachelors Degree       FINANCE         AUS
# 2209                   Bachelors Degree       FINANCE         AUS
# 2210                   Bachelors Degree       FINANCE         AUS
# 2211                   Bachelors Degree       FINANCE         AUS
# 2212                   Bachelors Degree       FINANCE         AUS
# 2489          High School or equivalent  CONSTRUCTION          UK
# 2524                   Bachelors Degree       FINANCE          UK
# 2624                   Bachelors Degree       FINANCE        NETH
# 2625                   Bachelors Degree       FINANCE          SW
# 2779        Some High School Coursework  CONSTRUCTION          UK
# 2817                   Bachelors Degree       FINANCE         NaN
# 2844          High School or equivalent  CONSTRUCTION          UK
# 2869                       Professional       FINANCE         GER
# 3051                   Bachelors Degree       FINANCE         GER
# 3064                       Professional       FINANCE          UK
# 3101                         Vocational       FINANCE         GER
# 3153        Some High School Coursework  CONSTRUCTION          SP
# 3154        Some High School Coursework  CONSTRUCTION          SP
# 3162                   Bachelors Degree       FINANCE         NaN
# 3257                      Certification  CONSTRUCTION          UK
# 3260        Some High School Coursework  CONSTRUCTION          UK
# 3265                         Vocational  CONSTRUCTION          UK
# 3293                         Vocational  CONSTRUCTION          CR
# 3308                     Masters Degree       FINANCE         USA
# 3361        Some High School Coursework  CONSTRUCTION          SP
# 3466                   Bachelors Degree       FINANCE          SW
#
#      user_country job_region user_region
# 38            USA        NaN           N
# 200            CR         UK          CR
# 268            IR          N          IR
# 645            IR          N          IR
# 894            CR         UK          CR
# 1167           JP          N          JP
# 1595           UK         CR          UK
# 1649          BRA          N         BRA
# 1731           UK         SP          UK
# 1736          USA        NaN           S
# 1802           JP          W          JP
# 1940           IR        NaN          IR
# 2021          USA         UK           M
# 2054           JP          W          JP
# 2094           IT          W          IT
# 2208          USA        AUS           W
# 2209          USA        AUS           W
# 2210          USA        AUS           S
# 2211          USA        AUS           W
# 2212          USA        AUS           W
# 2489           CR         UK          CR
# 2524           CR         UK          CR
# 2624          USA       NETH           W
# 2625          USA         SW           W
# 2779           CR         UK          CR
# 2817           UK        NaN          UK
# 2844           SP         UK          SP
# 2869          USA        GER           N
# 3051          USA        GER           N
# 3064          BRA         UK         BRA
# 3101          BEL        GER         BEL
# 3153           UK         SP          UK
# 3154           UK         SP          UK
# 3162          USA        NaN           W
# 3257           CR         UK          CR
# 3260           SP         UK          SP
# 3265           SP         UK          SP
# 3293           UK         CR          UK
# 3308           UK          W          UK
# 3361           UK         SP          UK
# 3466          USA         SW           N

# %% [markdown]
# #### Looks like the majority of the jobs are in finance: let's see if finance jobs are more likely to apply farther away

# %%
print('Percent of FINANCE jobs applying to same region: ', round(len(df[df.apply(lambda x: True if (x['JobType']=='FINANCE') & 
    (x['job_region']==x['user_region']) else False, axis=1)])/len(df[df['JobType']=='FINANCE']),2),'\n')

print('Percent of MEDICAL jobs applying to same region: ', round(len(df[df.apply(lambda x: True if (x['JobType']=='MEDICAL') & 
    (x['job_region']==x['user_region']) else False, axis=1)])/len(df[df['JobType']=='MEDICAL']),2),'\n')

print('Percent of CONSTRUCTION jobs applying to same region: ', round(len(df[df.apply(lambda x: True if (x['JobType']=='CONSTRUCTION') & 
    (x['job_region']==x['user_region']) else False, axis=1)])/len(df[df['JobType']=='CONSTRUCTION']),2),'\n')
# Out:
# Percent of FINANCE jobs applying to same region:  0.82
#
# Percent of MEDICAL jobs applying to same region:  0.9
#
# Percent of CONSTRUCTION jobs applying to same region:  0.94

# %% [markdown]
# #### Looks like finance jobs are less likely to apply to the same region, but not by a wide enough margin where I want to factor it into the model

# %% [markdown]
# ### Feature Correlations

# %% [markdown]
# #### I want to see if there's variance between variables and location, so let's create a column for users applying to jobs far away

# %%
df['state_diff'] = df.apply(lambda x: 1 if x['JobState'] != x['UserState'] else 0, axis=1)
df['region_diff'] = df.apply(lambda x: 1 if x['job_region'] != x['user_region'] else 0, axis=1)
df['country_diff'] = df.apply(lambda x: 1 if x['job_country'] != x['user_country'] else 0, axis=1)

# %%
df.sample(2)
# Out:
#                                     USERID  \
# 1250  33ea7cb9-e01f-4b4f-b069-d59ce700a7eb
# 1718  101d051f-56db-4256-b7f1-c97dbc80741a
#
#                                      JOBID  UserState  CAREERLEVEL  \
# 1250  ce7ae102-a5f3-4177-a609-5ababc073203  Wisconsin  Entry Level
# 1718  97a3d05e-34ae-4dad-ab85-5c36ffaf2321      Texas  Entry Level
#
#                          UserEd   JobState                      JobEd  \
# 1250                Unspecified  Wisconsin  High School or equivalent
# 1718  High School or equivalent      Texas              Certification
#
#            JobType job_country user_country job_region user_region  \
# 1250  CONSTRUCTION         USA          USA          M           M
# 1718  CONSTRUCTION         USA          USA          S           S
#
#       state_diff  region_diff  country_diff
# 1250           0            0             0
# 1718           0            0             0

# %%
#Create dictionary to get totals
def compare_totals(df, var):
    var_total  = df.groupby([var]).agg({'USERID':'count',"state_diff":"sum","region_diff":"sum","country_diff":"sum"}).reset_index()      
    totals = pd.Series(var_total['USERID'].values,index=var_total[var]).to_dict() 
    var_total['total'] = var_total[var].map(totals) 
    var_total['state_diff'] = round(var_total['state_diff']/var_total['total'],3)
    var_total['region_diff'] = round(var_total['region_diff']/var_total['total'],3)
    var_total['country_diff'] = round(var_total['country_diff']/var_total['total'],3)
    return var_total

# %%
compare_totals(df, 'CAREERLEVEL')
# Out:
#                                  CAREERLEVEL  USERID  state_diff  region_diff  \
# 0                                Entry Level     789       0.279        0.112
# 1  Executive (SVP, VP, Department Head, etc)     106       0.255        0.104
# 2                  Experienced (Non-Manager)    1288       0.229        0.122
# 3      Manager (Manager/Supervisor of Staff)     776       0.195        0.084
# 4     Senior Executive (President, CEO, etc)      30       0.133        0.067
# 5                      Student (High School)     232       0.134        0.043
# 6           Student (undergraduate/graduate)     381       0.199        0.102
#
#    country_diff  total
# 0         0.009    789
# 1         0.000    106
# 2         0.015   1288
# 3         0.010    776
# 4         0.000     30
# 5         0.017    232
# 6         0.008    381

# %% [markdown]
# #### Doesn't look like Career level is indicative of location differentials. Let's look at Job type

# %%
compare_totals(df, 'JobType')
# Out:
#         JobType  USERID  state_diff  region_diff  country_diff  total
# 0  CONSTRUCTION    2023       0.132        0.061         0.009   2023
# 1       FINANCE    1155       0.394        0.180         0.020   1155
# 2       MEDICAL     424       0.193        0.097         0.000    424

# %% [markdown]
# #### Compare job types with vars

# %%
#Create dictionary to get totals
def compare_jobtype_totals(df, var):
    df = pd.concat([df, pd.get_dummies(df['JobType'])], axis=1)
    var_total  = df.groupby([var]).agg({'USERID':'count','FINANCE':'sum','MEDICAL':'sum','CONSTRUCTION':'sum'}).reset_index()      
    totals = pd.Series(var_total['USERID'].values,index=var_total[var]).to_dict() 
    var_total['total'] = var_total[var].map(totals) 
    var_total['FINANCE'] = round(var_total['FINANCE']/var_total['total'],3)
    var_total['MEDICAL'] = round(var_total['MEDICAL']/var_total['total'],3)
    var_total['CONSTRUCTION'] = round(var_total['CONSTRUCTION']/var_total['total'],3)
    return var_total

compare_jobtype_totals(df, "UserEd")
# Out:
#                                UserEd  USERID  FINANCE  MEDICAL  CONSTRUCTION  \
# 0                    Associate Degree      71    0.099    0.268         0.634
# 1                    Bachelors Degree     248    0.435    0.149         0.415
# 2                       Certification      71    0.183    0.127         0.690
# 3                           Doctorate      20    0.750    0.100         0.150
# 4           High School or equivalent     316    0.057    0.136         0.807
# 5                      Masters Degree     226    0.841    0.062         0.097
# 6                        Professional      15    0.333    0.000         0.667
# 7   Some College Coursework Completed     166    0.163    0.114         0.723
# 8         Some High School Coursework      53    0.113    0.057         0.830
# 9                         Unspecified    2195    0.322    0.111         0.568
# 10                         Vocational      70    0.086    0.286         0.629
# 11           Vocational - High School     151    0.358    0.099         0.543
#
#     total
# 0      71
# 1     248
# 2      71
# 3      20
# 4     316
# 5     226
# 6      15
# 7     166
# 8      53
# 9    2195
# 10     70
# 11    151

# %%
compare_jobtype_totals(df, "JobEd")
# Out:
#                                 JobEd  USERID  FINANCE  MEDICAL  CONSTRUCTION  \
# 0                    Associate Degree     118    0.085    0.847         0.068
# 1                    Bachelors Degree     923    0.852    0.108         0.040
# 2                       Certification     254    0.000    0.362         0.638
# 3                           Doctorate      12    1.000    0.000         0.000
# 4           High School or equivalent    1666    0.016    0.034         0.950
# 5                      Masters Degree     161    0.820    0.180         0.000
# 6                        Professional     220    0.755    0.091         0.155
# 7   Some College Coursework Completed      43    0.488    0.302         0.209
# 8         Some High School Coursework     157    0.000    0.025         0.975
# 9                          Vocational      46    0.022    0.174         0.804
# 10           Vocational - High School       2    0.000    1.000         0.000
#
#     total
# 0     118
# 1     923
# 2     254
# 3      12
# 4    1666
# 5     161
# 6     220
# 7      43
# 8     157
# 9      46
# 10      2

# %% [markdown]
# #### Analysis: while data jobs see more applicants from different regions, the difference between the locations of data applicants and the location of nursing and transport applicants wasn’t significant enough to warrant inclusion in a model.

# %% [markdown]
# #### Similarly, I there's a slight increase in the likelihood of those further along in their careers to apply to jobs outside their state, but again the difference isn’t significant enough to warrant adding to the model.

# %% [markdown]
# ### Feature Selection & Engineering

# %%
list(df.job_country.unique())
# Out:
# ['USA',
#  nan,
#  'SP',
#  'UK',
#  'GER',
#  'FR',
#  'CR',
#  'IR',
#  'CAN',
#  'AUS',
#  'IT',
#  'NETH',
#  'SW']

# %% [markdown]
# #### Note: I'm removing user_state from the model. If I apply to a job in new york that someone in London also applied for, I don't want my recommendations to be affected by what other people in London are applying to.

# %%
#Feature Engineering
df_train = df[['CAREERLEVEL','job_region','JobState','job_region','job_country','JobEd', 'JobType']]
df_train=df_train.fillna(value=0)

# %% [markdown]
# # Weighting

# %% [markdown]
# ### I spent considerable time thinking about how to give certain variables more weight than others, as not all variables should be considered to have equal value in recommendations. For example, recommending an entry-level nursing job in Arizona that requires a bachelor’s degree for someone in Arizona who has a bachelor’s degree, is looking for an entry level position, but works in data would not be valuable.

# %% [markdown]
# ### **In order to put more weight on certain variables, I duplicated their columns: this will add an extra dimension to each observation’s vector and decrease its distance from observations that share that attribute’s value. I weighted the variables as follows:

# %% [markdown]
# #### •	Job type: 7

# %% [markdown]
# #### •	Job education: 4

# %% [markdown]
# #### •	Job state: 3

# %% [markdown]
# #### •	Job region:2

# %% [markdown]
# #### •	Job country: 2

# %% [markdown]
# #### •	User career: 1

# %%
def create_weights(df, weights):
    cols = list(df.columns)
    for i, col in enumerate(cols):        
        for x in range(0, weights[col]):
            #CREATE DUMMY VARIABLE FOR EACH VALUE IN COLUMNS WE CARE ABOUT
            df = pd.concat([df, pd.get_dummies(df[col])], axis=1)
    #drop columns not in dummy format
    df = df.drop(cols,axis=1)
    df=df.fillna(value=0)
    return df

# %%
weights = {'CAREERLEVEL':1, 'job_region':2,'job_country':2,'JobState':3,'JobEd':4, 'JobType':7}
df_train = create_weights(df_train, weights)

print('Number of Vars: ',len(list(df_train.columns)))
# Out:
# Number of Vars:  436

# %% [markdown]
# ### Here, I'm "inorganically" applying weights to the variables. It's more important that we recommend a job to a user that is in their field than is in their state (i.e., it's better to show a data position in new york to a data applicant living in california than to show them a nursing job in california.)

# %% [markdown]
# ### This is not the cleanest or most glamorous method, but it should have the intended effect.

# %% [markdown]
# #### Job type is most important, and after job type, the next most important should be job education level. The next most important variable is location, but if the states don't match, I want to suggest jobs in the general region, so I'm adding job_region. Finally, if there are multiple possibilites with those options, then we can look to see if users with similar educations and career levels applied.

# %% [markdown]
# #### The actual value of the weights is not as important as the size of the weights relative to each other.

# %% [markdown]
# #### I used job region so that if a position is not in the same state as the job previously applied to, positions in the same region will be prioritized over positions farther away. By using both region and state, it will prioritize regional jobs over non-regional jobs, but still award the most weight to jobs in the same state.

# %% [markdown]
# ### Train

# %%
knn_weight = NearestNeighbors(metric='cosine',algorithm='brute', n_neighbors=40)
knn_weight.fit(df_train)
distances, indices = knn_weight.kneighbors(df_train)

# %%
#Indicies output is in an array
print(indices[0])
# Out:
# [3204 3058 3059    0 1206 1622 1525  335 3428 1523    2 2017  815  329
#   814 3328  328  336  333 2579 2859  334 1205  327  326 2858  331  330
#  1522 1204  332 1203 3133 2526 2910 1519 1520 1521 3216 2860]

# %% [markdown]
# #### We run into a problem here: since different applicants apply to the same job, our model has multiple rows for the same job even though the vectors are different. With a nurse from Texas with a bachelors, Our model wants to first recommend a job that a different nurse from texas with a bachelors applied for, and second wants to recommend a job that a nurse from texas with an associates applied for, since the model sees them as different. However, they're the same job, so we have to delete those duplciates. We can see how the duplicates arise from the example below

# %%
df[df.JOBID=='356aa9a3-cdb8-4d88-8fb6-714dd04ba9bb']
# Out:
#                                    USERID  \
# 850  7767d3a3-1e80-4225-8a04-1daf22744546
# 851  7767d3a3-1e80-4225-8a04-1daf22744546
# 852  03a4b1e3-6504-4033-9d1a-5a70f06e6958
# 853  794c58f0-1929-4d22-8074-3c7339fb1f0e
# 854  5068bd5b-4a2c-4270-9f18-1163f86c69a7
# 855  57e06aa2-d564-4532-adac-c32c430580ea
# 856  195c64cb-9093-4e71-b42e-de5047e48838
# 857  e2ed7533-f1e6-4a51-985d-84149a76e199
# 858  cfa385a8-ccf6-45d3-8ddd-ad9a5c6ab467
# 859  9ff781af-03e0-4110-9ff7-201c32a8197e
# 860  cafe07c1-cd52-442f-b615-9e3f29909c17
# 861  d91ca2fd-cf8f-48f2-8a0a-78459b9698bc
# 862  50ceefd8-add7-49f7-92ea-a9718e2ba2c5
# 863  70440496-f173-4f7e-a3a6-d56b704bea4d
# 864  0b1158bd-a95c-4a40-ae29-383af8124330
# 865  55c0210b-021f-4801-b6ce-3e2fc7ce15e4
# 866  62a64977-be93-4c1c-8673-d9a6505d3c8f
# 867  52331d1b-52e2-4896-a58b-07d2e6d64b33
# 868  255dc2ab-6ce5-4a02-958b-46f56ae29119
# 869  190bb304-5df4-44b9-aafe-8a96031ca3c7
# 870  bbce30e3-7136-42ae-8c10-0804372644df
# 871  e646b3f1-4df2-43eb-81f0-4052a2ac39f0
# 872  117386d6-2fd9-48fa-98df-e91e88c83cbf
# 873  b68d9360-c2d3-43ed-84fe-d7a57feb6804
# 874  5f077f9e-881a-498d-a0e5-2b252e4b4641
# 875  140817e7-4b07-4e1e-9f4f-83426b7eb571
# 876  468ab22f-fa57-47d5-b23e-b9ce1415a0ed
# 877  2c59f01f-de84-4bd9-ac81-bbd7ef58a241
# 878  f5ec72f0-21ab-49a8-b29a-4d8b5b65d376
# 879  3f8223f0-4f8f-40c4-be67-983ad8f120f3
# 880  7a498caa-a39f-4cc1-b99d-1407f88b1ea7
# 881  fd09daff-0fe3-45ef-8936-5aaedaa6d91c
#
#                                     JOBID   UserState  \
# 850  356aa9a3-cdb8-4d88-8fb6-714dd04ba9bb    New York
# 851  356aa9a3-cdb8-4d88-8fb6-714dd04ba9bb    New York
# 852  356aa9a3-cdb8-4d88-8fb6-714dd04ba9bb    New York
# 853  356aa9a3-cdb8-4d88-8fb6-714dd04ba9bb    New York
# 854  356aa9a3-cdb8-4d88-8fb6-714dd04ba9bb    New York
# 855  356aa9a3-cdb8-4d88-8fb6-714dd04ba9bb    New York
# 856  356aa9a3-cdb8-4d88-8fb6-714dd04ba9bb    New York
# 857  356aa9a3-cdb8-4d88-8fb6-714dd04ba9bb    New York
# 858  356aa9a3-cdb8-4d88-8fb6-714dd04ba9bb    New York
# 859  356aa9a3-cdb8-4d88-8fb6-714dd04ba9bb    New York
# 860  356aa9a3-cdb8-4d88-8fb6-714dd04ba9bb  New Jersey
# 861  356aa9a3-cdb8-4d88-8fb6-714dd04ba9bb  New Jersey
# 862  356aa9a3-cdb8-4d88-8fb6-714dd04ba9bb    New York
# 863  356aa9a3-cdb8-4d88-8fb6-714dd04ba9bb    New York
# 864  356aa9a3-cdb8-4d88-8fb6-714dd04ba9bb    New York
# 865  356aa9a3-cdb8-4d88-8fb6-714dd04ba9bb    New York
# 866  356aa9a3-cdb8-4d88-8fb6-714dd04ba9bb    New York
# 867  356aa9a3-cdb8-4d88-8fb6-714dd04ba9bb    New York
# 868  356aa9a3-cdb8-4d88-8fb6-714dd04ba9bb    New York
# 869  356aa9a3-cdb8-4d88-8fb6-714dd04ba9bb    New York
# 870  356aa9a3-cdb8-4d88-8fb6-714dd04ba9bb    Illinois
# 871  356aa9a3-cdb8-4d88-8fb6-714dd04ba9bb    New York
# 872  356aa9a3-cdb8-4d88-8fb6-714dd04ba9bb    New York
# 873  356aa9a3-cdb8-4d88-8fb6-714dd04ba9bb    New York
# 874  356aa9a3-cdb8-4d88-8fb6-714dd04ba9bb    New York
# 875  356aa9a3-cdb8-4d88-8fb6-714dd04ba9bb    New York
# 876  356aa9a3-cdb8-4d88-8fb6-714dd04ba9bb    New York
# 877  356aa9a3-cdb8-4d88-8fb6-714dd04ba9bb    New York
# 878  356aa9a3-cdb8-4d88-8fb6-714dd04ba9bb    New York
# 879  356aa9a3-cdb8-4d88-8fb6-714dd04ba9bb    New York
# 880  356aa9a3-cdb8-4d88-8fb6-714dd04ba9bb    New York
# 881  356aa9a3-cdb8-4d88-8fb6-714dd04ba9bb    New York
#
#                                    CAREERLEVEL  \
# 850           Student (undergraduate/graduate)
# 851           Student (undergraduate/graduate)
# 852                  Experienced (Non-Manager)
# 853                  Experienced (Non-Manager)
# 854  Executive (SVP, VP, Department Head, etc)
# 855      Manager (Manager/Supervisor of Staff)
# 856                                Entry Level
# 857                                Entry Level
# 858      Manager (Manager/Supervisor of Staff)
# 859      Manager (Manager/Supervisor of Staff)
# 860                                Entry Level
# 861      Manager (Manager/Supervisor of Staff)
# 862           Student (undergraduate/graduate)
# 863           Student (undergraduate/graduate)
# 864           Student (undergraduate/graduate)
# 865                  Experienced (Non-Manager)
# 866  Executive (SVP, VP, Department Head, etc)
# 867                  Experienced (Non-Manager)
# 868      Manager (Manager/Supervisor of Staff)
# 869      Manager (Manager/Supervisor of Staff)
# 870           Student (undergraduate/graduate)
# 871                  Experienced (Non-Manager)
# 872                  Experienced (Non-Manager)
# 873                                Entry Level
# 874                  Experienced (Non-Manager)
# 875      Manager (Manager/Supervisor of Staff)
# 876           Student (undergraduate/graduate)
# 877                      Student (High School)
# 878                  Experienced (Non-Manager)
# 879                  Experienced (Non-Manager)
# 880                                Entry Level
# 881      Manager (Manager/Supervisor of Staff)
#
#                                 UserEd  JobState             JobEd  JobType  \
# 850                        Unspecified  New York  Associate Degree  MEDICAL
# 851                        Unspecified  New York  Associate Degree  MEDICAL
# 852                        Unspecified  New York  Associate Degree  MEDICAL
# 853                        Unspecified  New York  Associate Degree  MEDICAL
# 854                   Bachelors Degree  New York  Associate Degree  MEDICAL
# 855                   Bachelors Degree  New York  Associate Degree  MEDICAL
# 856                        Unspecified  New York  Associate Degree  MEDICAL
# 857                        Unspecified  New York  Associate Degree  MEDICAL
# 858                        Unspecified  New York  Associate Degree  MEDICAL
# 859                   Associate Degree  New York  Associate Degree  MEDICAL
# 860                        Unspecified  New York  Associate Degree  MEDICAL
# 861                        Unspecified  New York  Associate Degree  MEDICAL
# 862                        Unspecified  New York  Associate Degree  MEDICAL
# 863                        Unspecified  New York  Associate Degree  MEDICAL
# 864                        Unspecified  New York  Associate Degree  MEDICAL
# 865                         Vocational  New York  Associate Degree  MEDICAL
# 866                        Unspecified  New York  Associate Degree  MEDICAL
# 867                        Unspecified  New York  Associate Degree  MEDICAL
# 868                        Unspecified  New York  Associate Degree  MEDICAL
# 869                        Unspecified  New York  Associate Degree  MEDICAL
# 870                        Unspecified  New York  Associate Degree  MEDICAL
# 871                   Bachelors Degree  New York  Associate Degree  MEDICAL
# 872  Some College Coursework Completed  New York  Associate Degree  MEDICAL
# 873                   Bachelors Degree  New York  Associate Degree  MEDICAL
# 874                        Unspecified  New York  Associate Degree  MEDICAL
# 875  Some College Coursework Completed  New York  Associate Degree  MEDICAL
# 876                        Unspecified  New York  Associate Degree  MEDICAL
# 877                        Unspecified  New York  Associate Degree  MEDICAL
# 878                        Unspecified  New York  Associate Degree  MEDICAL
# 879                        Unspecified  New York  Associate Degree  MEDICAL
# 880                        Unspecified  New York  Associate Degree  MEDICAL
# 881                        Unspecified  New York  Associate Degree  MEDICAL
#
#     job_country user_country job_region user_region  state_diff  region_diff  \
# 850         USA          USA          N           N           0            0
# 851         USA          USA          N           N           0            0
# 852         USA          USA          N           N           0            0
# 853         USA          USA          N           N           0            0
# 854         USA          USA          N           N           0            0
# 855         USA          USA          N           N           0            0
# 856         USA          USA          N           N           0            0
# 857         USA          USA          N           N           0            0
# 858         USA          USA          N           N           0            0
# 859         USA          USA          N           N           0            0
# 860         USA          USA          N           N           1            0
# 861         USA          USA          N           N           1            0
# 862         USA          USA          N           N           0            0
# 863         USA          USA          N           N           0            0
# 864         USA          USA          N           N           0            0
# 865         USA          USA          N           N           0            0
# 866         USA          USA          N           N           0            0
# 867         USA          USA          N           N           0            0
# 868         USA          USA          N           N           0            0
# 869         USA          USA          N           N           0            0
# 870         USA          USA          N           M           1            1
# 871         USA          USA          N           N           0            0
# 872         USA          USA          N           N           0            0
# 873         USA          USA          N           N           0            0
# 874         USA          USA          N           N           0            0
# 875         USA          USA          N           N           0            0
# 876         USA          USA          N           N           0            0
# 877         USA          USA          N           N           0            0
# 878         USA          USA          N           N           0            0
# 879         USA          USA          N           N           0            0
# 880         USA          USA          N           N           0            0
# 881         USA          USA          N           N           0            0
#
#      country_diff
# 850             0
# 851             0
# 852             0
# 853             0
# 854             0
# 855             0
# 856             0
# 857             0
# 858             0
# 859             0
# 860             0
# 861             0
# 862             0
# 863             0
# 864             0
# 865             0
# 866             0
# 867             0
# 868             0
# 869             0
# 870             0
# 871             0
# 872             0
# 873             0
# 874             0
# 875             0
# 876             0
# 877             0
# 878             0
# 879             0
# 880             0
# 881             0

# %% [markdown]
# #### We have 40 neighbors (excessive, but ensuring that we have enough in case the first 30 are all the job above). Lets create a list for each that can be added as columns

# %%
matches = [x for x in range(1, 41)]

#Create empty list for neighbor quantity (1-40)
for x in range(1,len(matches)+1):
    locals()['match_{0}'.format(x)] = []

#append the jobID of each neighbor to the appropriate list
for i in range(0, len(df_train)):
    for x in range(1, len(matches) + 1):
        locals()['match_{0}'.format(x)].append(df['JOBID'].iloc[indices[i][x-1]])

# %% [markdown]
# #### Now, add the lists as columns

# %%
results = df.copy()
for x in range(1, len(matches)+1):
    results['match_{0}'.format(x)] = locals()['match_{0}'.format(x)]
print(results.columns)
# Out:
# Index(['USERID', 'JOBID', 'UserState', 'CAREERLEVEL', 'UserEd', 'JobState',
#        'JobEd', 'JobType', 'job_country', 'user_country', 'job_region',
#        'user_region', 'state_diff', 'region_diff', 'country_diff', 'match_1',
#        'match_2', 'match_3', 'match_4', 'match_5', 'match_6', 'match_7',
#        'match_8', 'match_9', 'match_10', 'match_11', 'match_12', 'match_13',
#        'match_14', 'match_15', 'match_16', 'match_17', 'match_18', 'match_19',
#        'match_20', 'match_21', 'match_22', 'match_23', 'match_24', 'match_25',
#        'match_26', 'match_27', 'match_28', 'match_29', 'match_30', 'match_31',
#        'match_32', 'match_33', 'match_34', 'match_35', 'match_36', 'match_37',
#        'match_38', 'match_39', 'match_40'],
#       dtype='object')

# %% [markdown]
# #### We can see below that numerous users are being recommended the same job as their 1st and 2nd match

# %%
results['duplicate']=results.apply(lambda x: True if x['match_1']==x['match_2'] else False, axis=1)
print('Number of users with identical first and second job matches: ', len(results[results.duplicate]))
# Out:
# Number of users with identical first and second job matches:  591

# %% [markdown]
# #### Lets use the function below to find the top 3 unique job numbers

# %%
def delete_duplicates(row):
    applied = row[0]
    uniques = list(set(row.values.tolist()))    
    if applied in uniques:
        uniques.remove(applied)
    row[1], row[2], row[3] = uniques[0], uniques[1], uniques[2]
    return row

# %%
results_test = results[['JOBID','match_1',
       'match_2', 'match_3', 'match_4', 'match_5', 'match_6', 'match_7',
       'match_8', 'match_9', 'match_10', 'match_11', 'match_12', 'match_13',
       'match_14', 'match_15', 'match_16', 'match_17', 'match_18', 'match_19',
       'match_20', 'match_21', 'match_22', 'match_23', 'match_24', 'match_25',
       'match_26', 'match_27', 'match_28', 'match_29', 'match_30', 'match_31',
       'match_32','match_33','match_34','match_35','match_36','match_37','match_38',
        'match_39','match_40',]]

results_test = results_test.apply(lambda x: delete_duplicates(x), axis=1)

# %% [markdown]
# #### Let's check to see if we got rid of the duplicates

# %%
results_test['duplicate']=results_test.apply(lambda x: True if x['match_1']==x['match_2'] else False, axis=1)
print('Number of users with identical first and second job matches: ',len(results_test[results_test.duplicate]))
results_test['duplicate']=results_test.apply(lambda x: True if x['match_2']==x['match_3'] else False, axis=1)
print('Number of users with identical second and third job matches: ', len(results_test[results_test.duplicate]))
results_test['duplicate']=results_test.apply(lambda x: True if x['match_1']==x['match_3'] else False, axis=1)
print('Number of users with identical first and third job matches: ', len(results_test[results_test.duplicate]))
results_test['duplicate']=results_test.apply(lambda x: True if (x['JOBID']==x['match_1']) or (x['JOBID']==x['match_2'])
                                             or (x['JOBID']==x['match_3']) else False, axis=1)
print('Number of users shown recommendation they previously applied to: ', len(results_test[results_test.duplicate]))
# Out:
# Number of users with identical first and second job matches:  0
# Number of users with identical second and third job matches:  0
# Number of users with identical first and third job matches:  0
# Number of users shown recommendation they previously applied to:  0

# %% [markdown]
# #### Perfect! Lets map those columns back onto the main results page

# %%
results['match_1'],results['match_2'], results['match_3'] = results_test['match_1'].tolist(),results_test['match_2'].tolist(), results_test['match_3'].tolist() 

results = results[['USERID', 'JOBID', 'UserState', 'CAREERLEVEL', 'UserEd', 'JobState','JobEd', 'JobType', 'job_country', 
           'user_country', 'job_region','user_region', 'state_diff', 'region_diff', 'country_diff', 'match_1','match_2', 
           'match_3']]

# %% [markdown]
# ### How did we do?

# %%
results_indices = df[['USERID', 'JOBID', 'CAREERLEVEL', 'JobState','job_region','JobEd', 'JobType']].set_index('JOBID')

sample = results[['USERID', 'JOBID', 'CAREERLEVEL', 'JobState','job_region','JobEd', 'JobType',
           'match_1','match_2', 'match_3']].sample(5)
for index, row in sample.iterrows():
    print('JOB: ','\n', row,'\n')
    print('Rec 1: ',results_indices.loc[sample['match_1'].loc[index]],'\n')
    print('Rec 2: ',results_indices.loc[sample['match_2'].loc[index]],'\n')
    print('Rec 3: ',results_indices.loc[sample['match_3'].loc[index]],'\n')
    print('\n\n\n')
# Out:
# JOB:
#  USERID          9c0f783c-b249-41a2-9e0a-e4cb46018be4
# JOBID           a3e34c0f-d175-4a88-9c8f-a40ff0ce7912
# CAREERLEVEL    Manager (Manager/Supervisor of Staff)
# JobState                                     Georgia
# job_region                                         S
# JobEd                      High School or equivalent
# JobType                                 CONSTRUCTION
# match_1         85fe685a-1cbf-4566-bde6-8079399eae2e
# match_2         5a84fbd7-be03-43e1-af95-e3c3e5fb15b7
# match_3         f168c43f-6114-4824-adca-bde6ddba6a8f
# Name: 121, dtype: object
#
# Rec 1:  USERID         b4ea148d-c0a2-40ba-bf91-a10f369a8aa7
# CAREERLEVEL                   Student (High School)
# JobState                                    Georgia
# job_region                                        S
# JobEd                     High School or equivalent
# JobType                                CONSTRUCTION
# Name: 85fe685a-1cbf-4566-bde6-8079399eae2e, dtype: object
#
# Rec 2:                                                                      USERID  \
# JOBID
# 5a84fbd7-be03-43e1-af95-e3c3e5fb15b7  c58c1ca9-a378-4f75-be0b-fc3d9c153242
# 5a84fbd7-be03-43e1-af95-e3c3e5fb15b7  8b4cd2bd-9903-408c-8a4f-098ca6bc72c1
# 5a84fbd7-be03-43e1-af95-e3c3e5fb15b7  8ca1a9ac-9b55-4a4b-94db-ba95e83e3f3b
# 5a84fbd7-be03-43e1-af95-e3c3e5fb15b7  5f808bb9-44e9-44cf-a212-bce0ce759a0a
# 5a84fbd7-be03-43e1-af95-e3c3e5fb15b7  8c4895e0-d8b7-4b0c-b16e-1237cd17b30d
# 5a84fbd7-be03-43e1-af95-e3c3e5fb15b7  8b986219-e7aa-469b-88a1-7bb4248e41a1
# 5a84fbd7-be03-43e1-af95-e3c3e5fb15b7  0e154b0e-9c5c-4ecb-8ac7-218971058de9
#
#                                                                     CAREERLEVEL  \
# JOBID
# 5a84fbd7-be03-43e1-af95-e3c3e5fb15b7                  Experienced (Non-Manager)
# 5a84fbd7-be03-43e1-af95-e3c3e5fb15b7                  Experienced (Non-Manager)
# 5a84fbd7-be03-43e1-af95-e3c3e5fb15b7                  Experienced (Non-Manager)
# 5a84fbd7-be03-43e1-af95-e3c3e5fb15b7  Executive (SVP, VP, Department Head, etc)
# 5a84fbd7-be03-43e1-af95-e3c3e5fb15b7                      Student (High School)
# 5a84fbd7-be03-43e1-af95-e3c3e5fb15b7           Student (undergraduate/graduate)
# 5a84fbd7-be03-43e1-af95-e3c3e5fb15b7      Manager (Manager/Supervisor of Staff)
#
#                                      JobState job_region  \
# JOBID
# 5a84fbd7-be03-43e1-af95-e3c3e5fb15b7  Georgia          S
# 5a84fbd7-be03-43e1-af95-e3c3e5fb15b7  Georgia          S
# 5a84fbd7-be03-43e1-af95-e3c3e5fb15b7  Georgia          S
# 5a84fbd7-be03-43e1-af95-e3c3e5fb15b7  Georgia          S
# 5a84fbd7-be03-43e1-af95-e3c3e5fb15b7  Georgia          S
# 5a84fbd7-be03-43e1-af95-e3c3e5fb15b7  Georgia          S
# 5a84fbd7-be03-43e1-af95-e3c3e5fb15b7  Georgia          S
#
#                                                           JobEd       JobType
# JOBID
# 5a84fbd7-be03-43e1-af95-e3c3e5fb15b7  High School or equivalent  CONSTRUCTION
# 5a84fbd7-be03-43e1-af95-e3c3e5fb15b7  High School or equivalent  CONSTRUCTION
# 5a84fbd7-be03-43e1-af95-e3c3e5fb15b7  High School or equivalent  CONSTRUCTION
# 5a84fbd7-be03-43e1-af95-e3c3e5fb15b7  High School or equivalent  CONSTRUCTION
# 5a84fbd7-be03-43e1-af95-e3c3e5fb15b7  High School or equivalent  CONSTRUCTION
# 5a84fbd7-be03-43e1-af95-e3c3e5fb15b7  High School or equivalent  CONSTRUCTION
# 5a84fbd7-be03-43e1-af95-e3c3e5fb15b7  High School or equivalent  CONSTRUCTION
#
# Rec 3:                                                                      USERID  \
# JOBID
# f168c43f-6114-4824-adca-bde6ddba6a8f  b1341464-8a95-4a1e-9dd5-daf7b53139d8
# f168c43f-6114-4824-adca-bde6ddba6a8f  bd501876-1437-4743-90de-7544c9d2e6ed
# f168c43f-6114-4824-adca-bde6ddba6a8f  4a10cd9e-b2d4-4d25-935a-a4730dc02320
# f168c43f-6114-4824-adca-bde6ddba6a8f  7294465f-6ea5-4b72-8b9f-f1c9be6e8e9a
# f168c43f-6114-4824-adca-bde6ddba6a8f  320b2db3-53cd-4004-af05-12f052090e7c
# f168c43f-6114-4824-adca-bde6ddba6a8f  469bb734-cc7e-402b-8ae6-ed3dbe9c9dd4
#
#                                                                 CAREERLEVEL  \
# JOBID
# f168c43f-6114-4824-adca-bde6ddba6a8f       Student (undergraduate/graduate)
# f168c43f-6114-4824-adca-bde6ddba6a8f              Experienced (Non-Manager)
# f168c43f-6114-4824-adca-bde6ddba6a8f                  Student (High School)
# f168c43f-6114-4824-adca-bde6ddba6a8f  Manager (Manager/Supervisor of Staff)
# f168c43f-6114-4824-adca-bde6ddba6a8f              Experienced (Non-Manager)
# f168c43f-6114-4824-adca-bde6ddba6a8f                  Student (High School)
#
#                                      JobState job_region  \
# JOBID
# f168c43f-6114-4824-adca-bde6ddba6a8f  Georgia          S
# f168c43f-6114-4824-adca-bde6ddba6a8f  Georgia          S
# f168c43f-6114-4824-adca-bde6ddba6a8f  Georgia          S
# f168c43f-6114-4824-adca-bde6ddba6a8f  Georgia          S
# f168c43f-6114-4824-adca-bde6ddba6a8f  Georgia          S
# f168c43f-6114-4824-adca-bde6ddba6a8f  Georgia          S
#
#                                                           JobEd       JobType
# JOBID
# f168c43f-6114-4824-adca-bde6ddba6a8f  High School or equivalent  CONSTRUCTION
# f168c43f-6114-4824-adca-bde6ddba6a8f  High School or equivalent  CONSTRUCTION
# f168c43f-6114-4824-adca-bde6ddba6a8f  High School or equivalent  CONSTRUCTION
# f168c43f-6114-4824-adca-bde6ddba6a8f  High School or equivalent  CONSTRUCTION
# f168c43f-6114-4824-adca-bde6ddba6a8f  High School or equivalent  CONSTRUCTION
# f168c43f-6114-4824-adca-bde6ddba6a8f  High School or equivalent  CONSTRUCTION
#
#
#
#
#
# JOB:
#  USERID         b0144507-2810-4f1e-9837-6c1f9408421f
# JOBID          e72c9e24-9e98-4d38-bdc5-4f672f22e92d
# CAREERLEVEL                   Student (High School)
# JobState                               Pennsylvania
# job_region                                        N
# JobEd                     High School or equivalent
# JobType                                CONSTRUCTION
# match_1        6ff3c82b-adae-4332-b4f1-70fd4f7e3471
# match_2        2708d28e-c526-4a3b-a0c3-c809387ab781
# match_3        390deeae-3fd7-416f-944f-f6f9744e2796
# Name: 596, dtype: object
#
# Rec 1:  USERID         fffb4388-8afd-4f09-91b2-4d6c56d5b7f1
# CAREERLEVEL               Experienced (Non-Manager)
# JobState                               Pennsylvania
# job_region                                        N
# JobEd                     High School or equivalent
# JobType                                CONSTRUCTION
# Name: 6ff3c82b-adae-4332-b4f1-70fd4f7e3471, dtype: object
#
# Rec 2:  USERID         6f15af68-edf3-46c0-9ee1-3e4f9dd9eb4a
# CAREERLEVEL                   Student (High School)
# JobState                               Pennsylvania
# job_region                                        N
# JobEd                     High School or equivalent
# JobType                                CONSTRUCTION
# Name: 2708d28e-c526-4a3b-a0c3-c809387ab781, dtype: object
#
# Rec 3:  USERID         c9c633ee-8a88-4e66-8b0f-f888da5fb806
# CAREERLEVEL               Experienced (Non-Manager)
# JobState                               Pennsylvania
# job_region                                        N
# JobEd                     High School or equivalent
# JobType                                CONSTRUCTION
# Name: 390deeae-3fd7-416f-944f-f6f9744e2796, dtype: object
#
#
#
#
#
# JOB:
#  USERID         7081eb2a-b394-4a43-9510-ead2fa110d7d
# JOBID          c422fe79-4b81-4aa3-a149-8eb7a624e20b
# CAREERLEVEL               Experienced (Non-Manager)
# JobState                                      Texas
# job_region                                        S
# JobEd                              Bachelors Degree
# JobType                                     FINANCE
# match_1        1627b8ab-5c57-4744-a58b-37b216a3a4e9
# match_2        c1977091-0e2b-4574-92c2-31765eb0bae6
# match_3        5571ab04-a7d9-48e2-aef7-44a9f63d31ed
# Name: 1000, dtype: object
#
# Rec 1:  USERID         e2836fea-87e6-402d-8ef3-2927ff6e66b5
# CAREERLEVEL               Experienced (Non-Manager)
# JobState                                      Texas
# job_region                                        S
# JobEd                              Bachelors Degree
# JobType                                     FINANCE
# Name: 1627b8ab-5c57-4744-a58b-37b216a3a4e9, dtype: object
#
# Rec 2:                                                                      USERID  \
# JOBID
# c1977091-0e2b-4574-92c2-31765eb0bae6  524427aa-fb12-4881-8a88-d6cf50ffe60f
# c1977091-0e2b-4574-92c2-31765eb0bae6  70700ce9-0f48-48b2-a465-1862daf199d5
# c1977091-0e2b-4574-92c2-31765eb0bae6  e0869810-c322-4479-8f62-fcadd6ddfe89
# c1977091-0e2b-4574-92c2-31765eb0bae6  d59a4184-8e79-42f9-9fd7-783e529681b4
#
#                                                            CAREERLEVEL  \
# JOBID
# c1977091-0e2b-4574-92c2-31765eb0bae6         Experienced (Non-Manager)
# c1977091-0e2b-4574-92c2-31765eb0bae6         Experienced (Non-Manager)
# c1977091-0e2b-4574-92c2-31765eb0bae6  Student (undergraduate/graduate)
# c1977091-0e2b-4574-92c2-31765eb0bae6         Experienced (Non-Manager)
#
#                                      JobState job_region             JobEd  \
# JOBID
# c1977091-0e2b-4574-92c2-31765eb0bae6    Texas          S  Bachelors Degree
# c1977091-0e2b-4574-92c2-31765eb0bae6    Texas          S  Bachelors Degree
# c1977091-0e2b-4574-92c2-31765eb0bae6    Texas          S  Bachelors Degree
# c1977091-0e2b-4574-92c2-31765eb0bae6    Texas          S  Bachelors Degree
#
#                                       JobType
# JOBID
# c1977091-0e2b-4574-92c2-31765eb0bae6  FINANCE
# c1977091-0e2b-4574-92c2-31765eb0bae6  FINANCE
# c1977091-0e2b-4574-92c2-31765eb0bae6  FINANCE
# c1977091-0e2b-4574-92c2-31765eb0bae6  FINANCE
#
# Rec 3:  USERID         0a134140-e06a-42c7-bf66-f02b28031c69
# CAREERLEVEL               Experienced (Non-Manager)
# JobState                                      Texas
# job_region                                        S
# JobEd                              Bachelors Degree
# JobType                                     FINANCE
# Name: 5571ab04-a7d9-48e2-aef7-44a9f63d31ed, dtype: object
#
#
#
#
#
# JOB:
#  USERID         80fd1941-fab1-4fff-b977-2b1262b256ff
# JOBID          b93b1658-b73d-4f85-ab9e-ecb74f2b4c04
# CAREERLEVEL                             Entry Level
# JobState                                   New York
# job_region                                        N
# JobEd                     High School or equivalent
# JobType                                     FINANCE
# match_1        d0bf9412-d898-40c1-905f-4ff84455319a
# match_2        61683fc7-2fc6-4c02-a7ae-96a927e59faf
# match_3        2c1ba949-88d4-45f1-9c68-dadf81e52514
# Name: 1288, dtype: object
#
# Rec 1:                                                                      USERID  \
# JOBID
# d0bf9412-d898-40c1-905f-4ff84455319a  4e227b61-12f7-4502-96ae-3c51c5800eae
# d0bf9412-d898-40c1-905f-4ff84455319a  86e989d5-7d9d-4b62-8a78-4e56f8f213ac
# d0bf9412-d898-40c1-905f-4ff84455319a  874723b2-d9ea-4f2c-85d2-363eada55211
# d0bf9412-d898-40c1-905f-4ff84455319a  b12a7cbf-59db-484d-bc98-3f37423f56c2
# d0bf9412-d898-40c1-905f-4ff84455319a  579c6701-5f4c-497a-ac67-a5d1927ebc62
#
#                                                                 CAREERLEVEL  \
# JOBID
# d0bf9412-d898-40c1-905f-4ff84455319a                            Entry Level
# d0bf9412-d898-40c1-905f-4ff84455319a  Manager (Manager/Supervisor of Staff)
# d0bf9412-d898-40c1-905f-4ff84455319a              Experienced (Non-Manager)
# d0bf9412-d898-40c1-905f-4ff84455319a  Manager (Manager/Supervisor of Staff)
# d0bf9412-d898-40c1-905f-4ff84455319a              Experienced (Non-Manager)
#
#                                       JobState job_region         JobEd  \
# JOBID
# d0bf9412-d898-40c1-905f-4ff84455319a  New York          N  Professional
# d0bf9412-d898-40c1-905f-4ff84455319a  New York          N  Professional
# d0bf9412-d898-40c1-905f-4ff84455319a  New York          N  Professional
# d0bf9412-d898-40c1-905f-4ff84455319a  New York          N  Professional
# d0bf9412-d898-40c1-905f-4ff84455319a  New York          N  Professional
#
#                                       JobType
# JOBID
# d0bf9412-d898-40c1-905f-4ff84455319a  FINANCE
# d0bf9412-d898-40c1-905f-4ff84455319a  FINANCE
# d0bf9412-d898-40c1-905f-4ff84455319a  FINANCE
# d0bf9412-d898-40c1-905f-4ff84455319a  FINANCE
# d0bf9412-d898-40c1-905f-4ff84455319a  FINANCE
#
# Rec 2:                                                                      USERID  \
# JOBID
# 61683fc7-2fc6-4c02-a7ae-96a927e59faf  663bfb8b-fb39-4841-b25e-72aa04faf01f
# 61683fc7-2fc6-4c02-a7ae-96a927e59faf  87ac2d47-d3b7-4717-a46a-31ddb84ff362
#
#                                                     CAREERLEVEL  JobState  \
# JOBID
# 61683fc7-2fc6-4c02-a7ae-96a927e59faf                Entry Level  New York
# 61683fc7-2fc6-4c02-a7ae-96a927e59faf  Experienced (Non-Manager)  New York
#
#                                      job_region             JobEd  JobType
# JOBID
# 61683fc7-2fc6-4c02-a7ae-96a927e59faf          N  Bachelors Degree  FINANCE
# 61683fc7-2fc6-4c02-a7ae-96a927e59faf          N  Bachelors Degree  FINANCE
#
# Rec 3:                                                                      USERID  \
# JOBID
# 2c1ba949-88d4-45f1-9c68-dadf81e52514  e9f590e6-262a-4145-9020-732f0fb59cf8
# 2c1ba949-88d4-45f1-9c68-dadf81e52514  2a5f4d53-60ac-43e3-a5b7-d8fdd6388dcb
# 2c1ba949-88d4-45f1-9c68-dadf81e52514  4c50602f-f4f7-4105-b0dc-3c36d68b5c97
# 2c1ba949-88d4-45f1-9c68-dadf81e52514  0d4aeb6d-b659-4c70-8d0c-8f915fdeec8d
# 2c1ba949-88d4-45f1-9c68-dadf81e52514  e1a0d99f-78c1-4877-b0af-c3c83bffeabc
# 2c1ba949-88d4-45f1-9c68-dadf81e52514  47f8b45e-5ad7-457d-80f2-457ef45a0a88
# 2c1ba949-88d4-45f1-9c68-dadf81e52514  c5264f7e-3169-40aa-a340-a37ff1265281
# 2c1ba949-88d4-45f1-9c68-dadf81e52514  0af78f6f-8f7d-4456-8aa2-38b98a4d0a2c
# 2c1ba949-88d4-45f1-9c68-dadf81e52514  8b664b71-7f37-4170-a733-c7392ef17514
# 2c1ba949-88d4-45f1-9c68-dadf81e52514  54ab3398-e5ba-45a3-bece-76fc50605c06
#
#                                                                 CAREERLEVEL  \
# JOBID
# 2c1ba949-88d4-45f1-9c68-dadf81e52514              Experienced (Non-Manager)
# 2c1ba949-88d4-45f1-9c68-dadf81e52514  Manager (Manager/Supervisor of Staff)
# 2c1ba949-88d4-45f1-9c68-dadf81e52514              Experienced (Non-Manager)
# 2c1ba949-88d4-45f1-9c68-dadf81e52514              Experienced (Non-Manager)
# 2c1ba949-88d4-45f1-9c68-dadf81e52514                            Entry Level
# 2c1ba949-88d4-45f1-9c68-dadf81e52514       Student (undergraduate/graduate)
# 2c1ba949-88d4-45f1-9c68-dadf81e52514                            Entry Level
# 2c1ba949-88d4-45f1-9c68-dadf81e52514              Experienced (Non-Manager)
# 2c1ba949-88d4-45f1-9c68-dadf81e52514                            Entry Level
# 2c1ba949-88d4-45f1-9c68-dadf81e52514              Experienced (Non-Manager)
#
#                                       JobState job_region             JobEd  \
# JOBID
# 2c1ba949-88d4-45f1-9c68-dadf81e52514  New York          N  Bachelors Degree
# 2c1ba949-88d4-45f1-9c68-dadf81e52514  New York          N  Bachelors Degree
# 2c1ba949-88d4-45f1-9c68-dadf81e52514  New York          N  Bachelors Degree
# 2c1ba949-88d4-45f1-9c68-dadf81e52514  New York          N  Bachelors Degree
# 2c1ba949-88d4-45f1-9c68-dadf81e52514  New York          N  Bachelors Degree
# 2c1ba949-88d4-45f1-9c68-dadf81e52514  New York          N  Bachelors Degree
# 2c1ba949-88d4-45f1-9c68-dadf81e52514  New York          N  Bachelors Degree
# 2c1ba949-88d4-45f1-9c68-dadf81e52514  New York          N  Bachelors Degree
# 2c1ba949-88d4-45f1-9c68-dadf81e52514  New York          N  Bachelors Degree
# 2c1ba949-88d4-45f1-9c68-dadf81e52514  New York          N  Bachelors Degree
#
#                                       JobType
# JOBID
# 2c1ba949-88d4-45f1-9c68-dadf81e52514  FINANCE
# 2c1ba949-88d4-45f1-9c68-dadf81e52514  FINANCE
# 2c1ba949-88d4-45f1-9c68-dadf81e52514  FINANCE
# 2c1ba949-88d4-45f1-9c68-dadf81e52514  FINANCE
# 2c1ba949-88d4-45f1-9c68-dadf81e52514  FINANCE
# 2c1ba949-88d4-45f1-9c68-dadf81e52514  FINANCE
# 2c1ba949-88d4-45f1-9c68-dadf81e52514  FINANCE
# 2c1ba949-88d4-45f1-9c68-dadf81e52514  FINANCE
# 2c1ba949-88d4-45f1-9c68-dadf81e52514  FINANCE
# 2c1ba949-88d4-45f1-9c68-dadf81e52514  FINANCE
#
#
#
#
#
# JOB:
#  USERID         4fd9bf29-90ae-43eb-b35e-74ed2a7ba191
# JOBID          d1a20e22-6b43-42a4-9d0f-b83f531eb586
# CAREERLEVEL                             Entry Level
# JobState                                     Madrid
# job_region                                       SP
# JobEd                     High School or equivalent
# JobType                                CONSTRUCTION
# match_1        b3e1abfb-05b5-436d-8a2c-3ecc639f35c1
# match_2        55c2035a-2727-47cf-be7a-da98d39ce7f4
# match_3        823342fd-76bb-4a5b-9bd5-7105e35b1bd7
# Name: 3166, dtype: object
#
# Rec 1:  USERID         b58e704e-e5cc-4d95-8f7d-2b28d9a0bd13
# CAREERLEVEL                   Student (High School)
# JobState                                     Madrid
# job_region                                       SP
# JobEd                   Some High School Coursework
# JobType                                CONSTRUCTION
# Name: b3e1abfb-05b5-436d-8a2c-3ecc639f35c1, dtype: object
#
# Rec 2:  USERID         cf37d552-3933-4ef4-a85b-0e98dbdefb87
# CAREERLEVEL               Experienced (Non-Manager)
# JobState                                     Madrid
# job_region                                       SP
# JobEd                     High School or equivalent
# JobType                                CONSTRUCTION
# Name: 55c2035a-2727-47cf-be7a-da98d39ce7f4, dtype: object
#
# Rec 3:  USERID         b58e704e-e5cc-4d95-8f7d-2b28d9a0bd13
# CAREERLEVEL                   Student (High School)
# JobState                                     Madrid
# job_region                                       SP
# JobEd                   Some High School Coursework
# JobType                                CONSTRUCTION
# Name: 823342fd-76bb-4a5b-9bd5-7105e35b1bd7, dtype: object

# %% [markdown]
# ## The recommendations look pretty good! Although messy, it looks like duplicating columns can function as a weighting algorithm for KNN!

# %% [markdown]
# #### In addition, a more sophisticated algorithm to recommend regional jobs would improve the model. While the model does well in recommending jobs in the same region for certain parts of the US (say, recommending a job in Pennsylvania to an applicant that lives in New Jersey), the same algorithm doesn’t apply as well for the Midwest and West Coast, where the algorithm will recommend a job in Texas to someone from Colorado (not an outrageous recommendation, but certainly not as ideal as NJ to PA). I also didn’t develop an efficient way to account for rows with certain variables blank: if a location is blank, it can skew recommendations since the algorithm considers it a match with other attributes that are blank.

# %% [markdown]
# #### Commentary: There are plenty of aspects that could be improved in this model. For one, empirical evidence regarding tradeoffs for applicants would be key: would a data analyst be more likely to apply to a job outside his or her state if the education requirement meets his/her own?

# %%
Let me know what you think! email: austintarullo@gmail.com
